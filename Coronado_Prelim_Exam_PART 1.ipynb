# %% [markdown]
# <a href="https://colab.research.google.com/github/JhanellaCoronado/CORONADO_CPE-018-CPE31S2-/blob/main/Coronado_Prelim_Exam_PART%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:** Coronado, Jhanella |
# **Section:** CPE 018 | **Date:** 01/27/26 | Prelim Exam

# %% [markdown]
# **Instructions:**
#
# . Write a Python script using OpenCV that:
#
#     Reads an image named "nature.jpg"
#     Converts it to grayscale
#     Resizes it to 300x300 pixels
#     Saves the result as "processed.jpg"

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = '/content/drive/MyDrive/CSV/nature.jpg'

img = cv2.imread(image_path)
if img is not None:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
resized = cv2.resize(gray, (300, 300))

cv2.imwrite("/content/drive/MyDrive/CSV/processed.jpg", resized)

print("Image processed and saved as processed.jpg")

cv2_imshow(resized)
# Out:
# Image processed and saved as processed.jpg
# <PIL.Image.Image image mode=L size=300x300>
